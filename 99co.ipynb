# %%
#importing libraries
import pandas as pd
import numpy as np

# %%
#reaading the data sets
df1=pd.read_csv("G:\99.co project\private-residential-property-price-index-by-type-of-property-base-quarter-2009-q1-100.csv");
df2=pd.read_csv("G:\99.co project\private-residential-property-price-index-base-quarter-2009-q1-100.csv")

# %%
#displaying the dataset
df1
# Out:
#      quarter                 level_1     level_2  value
# 0    1975-Q1  Residential Properties      Landed    7.4
# 1    1975-Q1  Residential Properties  Non-landed   10.5
# 2    1975-Q2  Residential Properties      Landed    7.7
# 3    1975-Q2  Residential Properties  Non-landed   11.2
# 4    1975-Q3  Residential Properties      Landed    7.8
# 5    1975-Q3  Residential Properties  Non-landed   11.5
# 6    1975-Q4  Residential Properties      Landed    7.9
# 7    1975-Q4  Residential Properties  Non-landed   11.5
# 8    1976-Q1  Residential Properties      Landed    7.9
# 9    1976-Q1  Residential Properties  Non-landed   11.5
# 10   1976-Q2  Residential Properties      Landed    8.0
# 11   1976-Q2  Residential Properties  Non-landed   11.7
# 12   1976-Q3  Residential Properties      Landed    8.0
# 13   1976-Q3  Residential Properties  Non-landed   11.7
# 14   1976-Q4  Residential Properties      Landed    8.0
# 15   1976-Q4  Residential Properties  Non-landed   11.5
# ...

# %%
#displaying the dataset
df2
# Out:
#      quarter                 level_1  value
# 0    1975-Q1  Residential Properties    8.9
# 1    1975-Q2  Residential Properties    9.1
# 2    1975-Q3  Residential Properties    9.1
# 3    1975-Q4  Residential Properties    9.1
# 4    1976-Q1  Residential Properties    9.5
# 5    1976-Q2  Residential Properties    9.5
# 6    1976-Q3  Residential Properties    9.8
# 7    1976-Q4  Residential Properties    9.5
# 8    1977-Q1  Residential Properties    9.5
# 9    1977-Q2  Residential Properties    9.5
# 10   1977-Q3  Residential Properties    9.5
# 11   1977-Q4  Residential Properties    9.1
# 12   1978-Q1  Residential Properties    9.1
# 13   1978-Q2  Residential Properties    9.5
# 14   1978-Q3  Residential Properties    9.5
# 15   1978-Q4  Residential Properties    9.8
# 16   1979-Q1  Residential Properties   10.4
# 17   1979-Q2  Residential Properties   10.9
# 18   1979-Q3  Residential Properties   11.9
# 19   1979-Q4  Residential Properties   12.7
# ...

# %%
#displaying the information
df1.info
# Out:
# <bound method DataFrame.info of      quarter                 level_1     level_2  value
# 0    1975-Q1  Residential Properties      Landed    7.4
# 1    1975-Q1  Residential Properties  Non-landed   10.5
# 2    1975-Q2  Residential Properties      Landed    7.7
# 3    1975-Q2  Residential Properties  Non-landed   11.2
# 4    1975-Q3  Residential Properties      Landed    7.8
# 5    1975-Q3  Residential Properties  Non-landed   11.5
# 6    1975-Q4  Residential Properties      Landed    7.9
# 7    1975-Q4  Residential Properties  Non-landed   11.5
# 8    1976-Q1  Residential Properties      Landed    7.9
# 9    1976-Q1  Residential Properties  Non-landed   11.5
# 10   1976-Q2  Residential Properties      Landed    8.0
# 11   1976-Q2  Residential Properties  Non-landed   11.7
# 12   1976-Q3  Residential Properties      Landed    8.0
# 13   1976-Q3  Residential Properties  Non-landed   11.7
# 14   1976-Q4  Residential Properties      Landed    8.0
# ...

# %%
#displaying the information
df2.info
# Out:
# <bound method DataFrame.info of      quarter                 level_1  value
# 0    1975-Q1  Residential Properties    8.9
# 1    1975-Q2  Residential Properties    9.1
# 2    1975-Q3  Residential Properties    9.1
# 3    1975-Q4  Residential Properties    9.1
# 4    1976-Q1  Residential Properties    9.5
# 5    1976-Q2  Residential Properties    9.5
# 6    1976-Q3  Residential Properties    9.8
# 7    1976-Q4  Residential Properties    9.5
# 8    1977-Q1  Residential Properties    9.5
# 9    1977-Q2  Residential Properties    9.5
# 10   1977-Q3  Residential Properties    9.5
# 11   1977-Q4  Residential Properties    9.1
# 12   1978-Q1  Residential Properties    9.1
# 13   1978-Q2  Residential Properties    9.5
# 14   1978-Q3  Residential Properties    9.5
# 15   1978-Q4  Residential Properties    9.8
# 16   1979-Q1  Residential Properties   10.4
# 17   1979-Q2  Residential Properties   10.9
# 18   1979-Q3  Residential Properties   11.9
# 19   1979-Q4  Residential Properties   12.7
# ...

# %%
#breaking the column(quarter) into 2 columns years and Quarters
df1.dropna(inplace = True)

# %%
new = df1["quarter"].str.split("-", n = 1, expand = True)

# %%
df1["year"]= new[0]

# %%
df1["Quarter"]= new[1]

# %%
df1.drop(columns =["quarter"], inplace = True) #deleting the original column

# %%
#displaying the new dataframe
df1
# Out:
#                     level_1     level_2  value  year Quarter
# 0    Residential Properties      Landed    7.4  1975      Q1
# 1    Residential Properties  Non-landed   10.5  1975      Q1
# 2    Residential Properties      Landed    7.7  1975      Q2
# 3    Residential Properties  Non-landed   11.2  1975      Q2
# 4    Residential Properties      Landed    7.8  1975      Q3
# 5    Residential Properties  Non-landed   11.5  1975      Q3
# 6    Residential Properties      Landed    7.9  1975      Q4
# 7    Residential Properties  Non-landed   11.5  1975      Q4
# 8    Residential Properties      Landed    7.9  1976      Q1
# 9    Residential Properties  Non-landed   11.5  1976      Q1
# 10   Residential Properties      Landed    8.0  1976      Q2
# 11   Residential Properties  Non-landed   11.7  1976      Q2
# 12   Residential Properties      Landed    8.0  1976      Q3
# 13   Residential Properties  Non-landed   11.7  1976      Q3
# ...

# %%
#breaking the column(quarter) into 2 columns years and Quarters
df2.dropna(inplace = True)

# %%
new = df2["quarter"].str.split("-", n = 1, expand = True)

# %%
df2["year"]= new[0]

# %%
df2["Quarter"]= new[1]

# %%
df2.drop(columns =["quarter"], inplace = True) #deleting the original column

# %%
#displaying the dataframe
df2
# Out:
#                     level_1  value  year Quarter
# 0    Residential Properties    8.9  1975      Q1
# 1    Residential Properties    9.1  1975      Q2
# 2    Residential Properties    9.1  1975      Q3
# 3    Residential Properties    9.1  1975      Q4
# 4    Residential Properties    9.5  1976      Q1
# 5    Residential Properties    9.5  1976      Q2
# 6    Residential Properties    9.8  1976      Q3
# 7    Residential Properties    9.5  1976      Q4
# 8    Residential Properties    9.5  1977      Q1
# 9    Residential Properties    9.5  1977      Q2
# 10   Residential Properties    9.5  1977      Q3
# 11   Residential Properties    9.1  1977      Q4
# 12   Residential Properties    9.1  1978      Q1
# 13   Residential Properties    9.5  1978      Q2
# 14   Residential Properties    9.5  1978      Q3
# 15   Residential Properties    9.8  1978      Q4
# 16   Residential Properties   10.4  1979      Q1
# 17   Residential Properties   10.9  1979      Q2
# ...

# %%
#replacing the values of landed and non-landed by 1s and 0s respectively
df1=df1.replace(regex=['Landed'], value=1)
df1=df1.replace(regex=['Non-landed'], value=0)

# %%
#displaying the dataframe
df1
# Out:
#                     level_1  level_2  value  year Quarter
# 0    Residential Properties        1    7.4  1975      Q1
# 1    Residential Properties        0   10.5  1975      Q1
# 2    Residential Properties        1    7.7  1975      Q2
# 3    Residential Properties        0   11.2  1975      Q2
# 4    Residential Properties        1    7.8  1975      Q3
# 5    Residential Properties        0   11.5  1975      Q3
# 6    Residential Properties        1    7.9  1975      Q4
# 7    Residential Properties        0   11.5  1975      Q4
# 8    Residential Properties        1    7.9  1976      Q1
# 9    Residential Properties        0   11.5  1976      Q1
# 10   Residential Properties        1    8.0  1976      Q2
# 11   Residential Properties        0   11.7  1976      Q2
# 12   Residential Properties        1    8.0  1976      Q3
# 13   Residential Properties        0   11.7  1976      Q3
# 14   Residential Properties        1    8.0  1976      Q4
# ...

# %%
#displaying the dataframe
df2
# Out:
#                     level_1  value  year Quarter
# 0    Residential Properties    8.9  1975      Q1
# 1    Residential Properties    9.1  1975      Q2
# 2    Residential Properties    9.1  1975      Q3
# 3    Residential Properties    9.1  1975      Q4
# 4    Residential Properties    9.5  1976      Q1
# 5    Residential Properties    9.5  1976      Q2
# 6    Residential Properties    9.8  1976      Q3
# 7    Residential Properties    9.5  1976      Q4
# 8    Residential Properties    9.5  1977      Q1
# 9    Residential Properties    9.5  1977      Q2
# 10   Residential Properties    9.5  1977      Q3
# 11   Residential Properties    9.1  1977      Q4
# 12   Residential Properties    9.1  1978      Q1
# 13   Residential Properties    9.5  1978      Q2
# 14   Residential Properties    9.5  1978      Q3
# 15   Residential Properties    9.8  1978      Q4
# 16   Residential Properties   10.4  1979      Q1
# 17   Residential Properties   10.9  1979      Q2
# ...

# %%
#creating new dataframew to divide the original dataframe to landed and non landed
df11 = df1[df1['level_2'] > 0] 
df12 = df1[df1['level_2'] == 0]

# %%
#displaying the dataframe
df11
# Out:
#                     level_1  level_2  value  year Quarter
# 0    Residential Properties        1    7.4  1975      Q1
# 2    Residential Properties        1    7.7  1975      Q2
# 4    Residential Properties        1    7.8  1975      Q3
# 6    Residential Properties        1    7.9  1975      Q4
# 8    Residential Properties        1    7.9  1976      Q1
# 10   Residential Properties        1    8.0  1976      Q2
# 12   Residential Properties        1    8.0  1976      Q3
# 14   Residential Properties        1    8.0  1976      Q4
# 16   Residential Properties        1    7.9  1977      Q1
# 18   Residential Properties        1    7.9  1977      Q2
# 20   Residential Properties        1    7.7  1977      Q3
# 22   Residential Properties        1    7.6  1977      Q4
# 24   Residential Properties        1    7.5  1978      Q1
# 26   Residential Properties        1    7.6  1978      Q2
# 28   Residential Properties        1    7.9  1978      Q3
# ...

# %%
#displaying the dataframe
df12
# Out:
#                     level_1  level_2  value  year Quarter
# 1    Residential Properties        0   10.5  1975      Q1
# 3    Residential Properties        0   11.2  1975      Q2
# 5    Residential Properties        0   11.5  1975      Q3
# 7    Residential Properties        0   11.5  1975      Q4
# 9    Residential Properties        0   11.5  1976      Q1
# 11   Residential Properties        0   11.7  1976      Q2
# 13   Residential Properties        0   11.7  1976      Q3
# 15   Residential Properties        0   11.5  1976      Q4
# 17   Residential Properties        0   11.5  1977      Q1
# 19   Residential Properties        0   11.5  1977      Q2
# 21   Residential Properties        0   11.5  1977      Q3
# 23   Residential Properties        0   11.5  1977      Q4
# 25   Residential Properties        0   11.5  1978      Q1
# 27   Residential Properties        0   11.7  1978      Q2
# 29   Residential Properties        0   11.7  1978      Q3
# ...

# %%
#renaming the column names
df11.rename(columns = {'value':'value_landed'}, inplace = True)
df12.rename(columns = {'value':'value_non-landed'}, inplace = True) 
#deleting second column which has no further significance 
del df11['level_2']
del df12['level_2']
# Out:
# C:\Users\KIIT\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df11
# Out:
#                     level_1  value_landed  year Quarter
# 0    Residential Properties           7.4  1975      Q1
# 2    Residential Properties           7.7  1975      Q2
# 4    Residential Properties           7.8  1975      Q3
# 6    Residential Properties           7.9  1975      Q4
# 8    Residential Properties           7.9  1976      Q1
# 10   Residential Properties           8.0  1976      Q2
# 12   Residential Properties           8.0  1976      Q3
# 14   Residential Properties           8.0  1976      Q4
# 16   Residential Properties           7.9  1977      Q1
# 18   Residential Properties           7.9  1977      Q2
# 20   Residential Properties           7.7  1977      Q3
# 22   Residential Properties           7.6  1977      Q4
# 24   Residential Properties           7.5  1978      Q1
# 26   Residential Properties           7.6  1978      Q2
# 28   Residential Properties           7.9  1978      Q3
# 30   Residential Properties           7.9  1978      Q4
# ...

# %%
#merging 2 columns from a dataset to make a new dataframe
dataset=pd.merge(df11, df12, how='inner')

# %%
#merging 2 columns from a dataset to make a new dataframe
dfa=pd.merge(dataset, df2, how='inner')

# %%
dfa
# Out:
#                     level_1  value_landed  year Quarter  value_non-landed  \
# 0    Residential Properties           7.4  1975      Q1              10.5
# 1    Residential Properties           7.7  1975      Q2              11.2
# 2    Residential Properties           7.8  1975      Q3              11.5
# 3    Residential Properties           7.9  1975      Q4              11.5
# 4    Residential Properties           7.9  1976      Q1              11.5
# 5    Residential Properties           8.0  1976      Q2              11.7
# 6    Residential Properties           8.0  1976      Q3              11.7
# 7    Residential Properties           8.0  1976      Q4              11.5
# 8    Residential Properties           7.9  1977      Q1              11.5
# 9    Residential Properties           7.9  1977      Q2              11.5
# 10   Residential Properties           7.7  1977      Q3              11.5
# 11   Residential Properties           7.6  1977      Q4              11.5
# ...

# %%
#deleting a column from the dataset
del dfa['level_1']

# %%
#replacing the Q1,Q2,Q3,Q4 with 1,2,3,4
dfa=dfa.replace('Q1',1)
dfa=dfa.replace('Q2',2)
dfa=dfa.replace('Q3',3)
dfa=dfa.replace('Q4',4)

# %%
dfa
# Out:
#      value_landed  year  Quarter  value_non-landed  value
# 0             7.4  1975        1              10.5    8.9
# 1             7.7  1975        2              11.2    9.1
# 2             7.8  1975        3              11.5    9.1
# 3             7.9  1975        4              11.5    9.1
# 4             7.9  1976        1              11.5    9.5
# 5             8.0  1976        2              11.7    9.5
# 6             8.0  1976        3              11.7    9.8
# 7             8.0  1976        4              11.5    9.5
# 8             7.9  1977        1              11.5    9.5
# 9             7.9  1977        2              11.5    9.5
# 10            7.7  1977        3              11.5    9.5
# 11            7.6  1977        4              11.5    9.1
# 12            7.5  1978        1              11.5    9.1
# 13            7.6  1978        2              11.7    9.5
# 14            7.9  1978        3              11.7    9.5
# ...

# %%
#preparing the x and y axes
x=dfa.iloc[0,3]
y=dfa.iloc[4]

# %%
x
# Out:
# 10.5

# %% [raw]
# y

# %%
#checking for any null values
dfa.isnull().sum()
# Out:
# value_landed        0
# year                0
# Quarter             0
# value_non-landed    0
# value               0
# dtype: int64

# %%
#importing seaborn and matplotlib
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#plotting a heatmap for the various columns
sns.heatmap(dfa.corr())

# %%
#plotting a displot
sns.distplot(dfa['value'],color='blue')
# Out:
# C:\Users\KIIT\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.boxplot(x='value_landed',y='value',data=dfa,color='red')

# %%
#plotting a boxplot
sns.boxplot(x='value_non-landed',y='value',data=dfa,color='red')

# %%
#importing the train test split
from sklearn.model_selection import train_test_split
dfa
# Out:
#      value_landed  year  Quarter  value_non-landed  value
# 0             7.4  1975        1              10.5    8.9
# 1             7.7  1975        2              11.2    9.1
# 2             7.8  1975        3              11.5    9.1
# 3             7.9  1975        4              11.5    9.1
# 4             7.9  1976        1              11.5    9.5
# 5             8.0  1976        2              11.7    9.5
# 6             8.0  1976        3              11.7    9.8
# 7             8.0  1976        4              11.5    9.5
# 8             7.9  1977        1              11.5    9.5
# 9             7.9  1977        2              11.5    9.5
# 10            7.7  1977        3              11.5    9.5
# 11            7.6  1977        4              11.5    9.1
# 12            7.5  1978        1              11.5    9.1
# 13            7.6  1978        2              11.7    9.5
# 14            7.9  1978        3              11.7    9.5
# ...

# %%
#plotting a graph of value non-landed vs value
ax=dfa.plot(kind='scatter',x='value_non-landed',y='value')
ax.set_xlabel("non landed value")

ax.set_xlabel("landed value")
# Out:
# Text(0.5, 0, 'landed value')

# %%
#plotting a graph of value landed vs value
plt.figure(figsize=(16, 8))
plt.scatter(dfa.value_landed,dfa.value)
plt.xlabel('value of landed house estimation')
plt.show('value')

# %%
#importing sklearn
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
#choosing x and y axes
X=dfa.iloc[0,3]
y=dfa.iloc[5]

# %%
#plotting an lmplot of value landed vs value
plt.figure(figsize=(16, 8))
sns.lmplot('value_landed','value',data=dfa)

# %%
#plotting an lmplot of value non-landed vs value
sns.lmplot('value_non-landed','value',data=dfa)

# %%
plt.figure(figsize=(16, 8))
plt.bar(dfa.year,dfa.value)
plt.xlabel('year')
plt.ylabel('value')
plt.xticks(dfa.year,dfa.value)
plt.title('Market Valuation')
plt.show()

# %%
#plotting bar graph of year and value 
index = np.arange(len(dfa.year))
plt.bar(index, dfa.value)
plt.xlabel('year')
plt.ylabel('value')
plt.xticks(index, dfa.value)
plt.title('Market prediction')
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
x = pd.DataFrame(np.c_[dfa['value_landed'], dfa['value_non-landed']], columns=['value_landed','value_non-landed'])
y = dfa['value']

# %%
#using regression
from sklearn.linear_model import LinearRegression
import numpy as np
#maximising the value of random-state
ts_score=[]
for j in range(100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.1,random_state=j)
    lr=LinearRegression().fit(x_train,y_train)
    ts_score.append(lr.score(x_test,y_test))
rs=ts_score.index(np.max(ts_score))
rs
# Out:
# 68

# %%
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#dividing the dataset between train and test sets
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.5,random_state=rs)

# %%
x_train
# Out:
#      value_landed  value_non-landed
# 39           33.4              33.1
# 74           79.4              65.4
# 62           41.5              42.7
# 126          89.2              90.0
# 133         117.8             129.0
# 58           36.9              38.7
# 101         101.0             100.4
# 52           32.6              30.7
# 4             7.9              11.5
# 9             7.9              11.5
# 22           16.2              25.8
# 123          85.6              84.4
# 161         164.4             139.8
# 66           46.5              47.5
# 93           97.2              85.4
# 14            7.9              11.7
# 89          128.9             110.9
# 88          129.9             111.9
# 3             7.9              11.5
# 171         152.9             135.6
# 157         172.9             144.5
# 150         173.9             142.3
# 113          83.8              80.2
# 148         171.2             141.0
# 83          135.1             105.5
# ...

# %%
dfa.isnull().sum()
# Out:
# value_landed        0
# year                0
# Quarter             0
# value_non-landed    0
# value               0
# dtype: int64

# %%
#fitting the dataset to the model
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#finding the coeddicient of the graph of the given model
reg.coef_
# Out:
# array([0.35970836, 0.62362617])

# %%
#finding the intercept
reg.intercept_
# Out:
# 0.28452806852128276

# %%
#making the prediction
y_pred=reg.predict(x_test)

# %%
y_pred
# Out:
# array([ 81.62290853, 124.62511728,  11.2261306 ,  35.38233696,
#         80.74514113,  38.30849166,  95.13056237,  10.31473775,
#         34.13098642, 139.23125182, 143.85741733,  32.48511694,
#         38.20801034,  27.93284344,  82.14096757,  34.46625334,
#        151.10281275,  12.91461202,  79.67305221,  81.26320017,
#         35.98720006,  81.61098409, 138.87388884,  83.6519402 ,
#         38.33742634,  80.0040234 ,  70.87347966, 106.2719424 ,
#         96.64407789, 135.8544865 , 120.35495696,  29.22799105,
#         98.61798062,  63.80754337, 150.42386012,  41.76697522,
#        109.12595791,  37.74977101,  26.34348556, 147.12861552,
#         37.31792346, 149.43837773, 150.32142846,  34.92234481,
#         37.33024294,  19.14813327,  31.5928822 , 113.35158082,
#         90.40097759, 155.22773195,  33.9673524 ,  80.90818258,
#        137.72751286,  86.39100705, 107.59348179, 149.7410068 ,
#         25.10287433,  90.36735214,  30.99330243, 145.04210953,
# ...

# %%
#calculating the score of the prediction
from sklearn.metrics import r2_score
r2_score(y_pred,y_test)
# Out:
# 0.9988244680553576
